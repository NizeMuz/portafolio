# %% [markdown]
# <a href="https://colab.research.google.com/github/NizeMuz/portafolio/blob/main/codigo_guia_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # cuaderno de ejercicos python victoria alejandra pasten vargas

# %% [markdown]
# Guia phyton

# %% [markdown]
# 1.-sumar 2 numeros leidos por teclado y escribir sus resultados

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# inicio
A=0; B=0;C=0
A= int(input("ingrese el primer numero "))
B= int(input("ingrese el segundo numero "))
C= A + B 
print("la suma es", C)
#FIN

# %% [markdown]
# 2.- sumar 100 numeros leidos por teclado

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
2# inicio
s=0; num=0;
for i in range(0,3):
  num = int(input("ingrese un numero  "))
  s = s + num
print("la suma es ", s)
# FIN

# %% [markdown]
# 3.- Sumar N números. El valor de N se debe leer previamente por teclado.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
1 # incio 
n=0; s=0; num=0;
n= int(input("ingrese la cantidad de numeros que desea sumar"))
while n > 0 :
  num = int(input("ingrese un numero "))
  s = s + num 
  n = n - 1 
print( "la suma es " , s )
#fin
# Out:
# ingrese la cantidad de numeros que desea sumar2
# ingrese un numero 5
# ingrese un numero 5
# la suma es  10

# %% [markdown]
# 4.-**mostrar en pantalla los 100 primeros numeros pares **

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# inicio
num=0; n=100; par=2;
while n > 0:
 par = par + 2;
 n= n - 1;
 print("los numeros pares son ", par)
# FIN

# %% [markdown]
# 5 . Elabore un algoritmo que permita leer dos valores distintos, determinar cual de los dos
# valores es el mayor y escribirlo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# inicio 
a = 0; b = 0;
while a == b:
  print("escribir dos numeros distintos ")
  a = int(input("ingrese a "))
  b = int(input("ingrese b "))
if a > b:
  print("el numero mayor es ", a)
else:
  print("el numero mayor es ", b)
#fin

# %% [markdown]
# 6.-Desarrolle un algoritmo que permita leer un valor cualquiera N y escriba si dicho
# número es par o impar.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#inicio 
num = 0 
num = int(input("ingrese el numero"))
while num > 1:
  num = num - 2
if num == 0 :
  print("el numero es par ")
else:
  print("el numero es impar")
#fin

# %% [markdown]
# 7.-Elabore un algoritmo que permita leer tres valores y almacenarlos en las variables A, B y
# C respectivamente. El algoritmo debe imprimir cual es el mayor y cual es el menor.
# Recuerde constatar que los tres valores introducidos por el teclado sean valores
# distintos. Presente un mensaje de alerta en caso de que se detecte la introducción de
# valores iguales.

# %% [markdown]
# ![7 captura.PNG](data:image/png;base64,...)

# %%
#inicio 
a = 0; b = 0; c = 0;
while a == b or a == c or b == c:
  print("Digite el primer número ")
  a = input()
  print("Digite el segundo número ")
  b = input()
  print("Digite el tercer número ")
  c = input()
if a > b:
  if a > c:
    print("El mayor es ",a)
else:  
  if b > a:
    if b > c:
      print("El mayor es ",b)
if c > a:
  if c > b:
    print("El mayor es ",c)
if a < b:
  if a < c:
    print("El menor es ", a)
else:
  if b < a:
    if b < c:
      print("El menor es ",b)
if c < a:
    if c < b:
      print("el menor es ", c)
#fin

# %% [markdown]
# 8.- Desarrolle un algoritmo que realice la sumatoria de los números enteros comprendidos
# entre el 1 y el 10, es decir, 1 + 2 + 3 + …. + 10, y muestre el resultado por pantalla.

# %% [markdown]
# ![8 captura.PNG](data:image/png;base64,...)

# %%
#inicio 
sum =0; num =0;
while num < 10:
  num = num + 1
  sum = sum + num 
print("la suma es ", sum)
# fin

# %% [markdown]
# 9.-Desarrolle un algoritmo que realice la sumatoria de los números enteros múltiplos de 5,
# comprendidos entre el 1 y el 100, es decir, 5 + 10 + 15 +…. + 100. El programa deberá
# imprimir los números y finalmente la sumatoria.

# %% [markdown]
# ![9 catura.PNG](data:image/png;base64,...)

# %%
#inicio 
sum=0; multiplo = 0;
while multiplo < 100:
  multiplo = multiplo + 5; 
  sum = sum + multiplo
  print("los multiplo son", multiplo)
print("la suma es", sum)
# fin

# %% [markdown]
# 10.- La sucesión de Fibonacci se define de la siguiente forma: a1 =1, a2 =1 y an =an-1+an-2
# para n>2, es decir los dos primeros son 1 y el resto cada uno es la suma de los dos
# anteriores, los primeros son: 1, 1, 2, 3, 5, 8, 13, 21, ... Calcular el Enésimo término de la
# sucesión.

# %% [markdown]
# ![10 captura.PNG](data:image/png;base64,...)

# %%
#inicio
a1=1; a2=1; a3=0; n=0; cant=2;
print("ingrese cantidad de fibonacci a representar")
n = int(input())
while cant < n:
  a3 = a2 + a1
  a2 = a3
  a1 = a2
  cant = cant + 1
  print(a3)
#fin

# %% [markdown]
# 11.-Hacer un algoritmo que lea N números, calcule y escriba la suma de los pares y el
# producto de los impares.

# %% [markdown]
# ![11.PNG](data:image/png;base64,...)

# %%
#inicio
impar = 1; par =0; n =0; num =0; numero = 0;
print("ingrese la cantidad de numeros a leer")
n = int(input())
while n < 0:
  numero = int(input())
  num = numero
  while num > 1:
    num = num - 2
if num == 0:
  par = par + numero
else:
  impar = impar * numero
n = n - 1
print("el producto impar es ",impar)
print("la suma es ", par)

# %% [markdown]
# 12.-Hacer el algoritmo para calcular el factorial de N (N!=1·2·3·...·N).

# %% [markdown]
# ![12.PNG](data:image/png;base64,...)

# %%
#inicio 
num = 1; n = 0; factorial = 0
print("ingrese el factorial a calcular")
n = int(input())
while n > 0:
  num = num * n 
  n = n - 1
print("el factorial  es ", num)
#fin

# %% [markdown]
# 13.-Hacer un algoritmo para calcular el máximo de N números leídos desde el teclado.

# %% [markdown]
# ![13.PNG](data:image/png;base64,...)

# %%
# inicio
num = 0; n = 0; mayor = 0;
print("ingrese cantidad de numeros ")
n = int(input())
while n > 0:
  num = int(input())
  if num > mayor:
    mayor = num
  n = n - 1
print("el numero mayor es ",mayor)
#fin
